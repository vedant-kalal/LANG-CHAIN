# %% [markdown]
# BUILT IN SEARCH TOOL

# %%
from langchain_community.tools import DuckDuckGoSearchRun

search_tool = DuckDuckGoSearchRun()

results = search_tool.invoke('top news in india today')
print(results)
# Out:
# 1 hour ago - Check today's top 10 news stories, headline news, breaking news, latest news, politics news, sports news, entertainment news and business news on Times of India 10 hours ago - Despite winning 29 out of their last 36 T20Is, Team India have one big area of concern according to former cricketer Dinesh Karthik. Following the death of a 27-year-old software engineer whose car plunged into a water-filled pit at a construction site in Sector 150, the Noida Authority has terminated the services of a junior engineer. 2 hours ago - Antonio Sanz, regional health minister for the Andalusia region where the crash happened, said officials told him they fear the death toll may rise further as rescue ops are underway ... India's public health spending remains below 2% of GDP , far ... September 22, 2025 - Latest News · Several Indian Films Make It To Oscar Eligibility List · India: Aware Of America’s 500% Tariff Bid, Acting With Great Care · Modi Not Calling Trump Stalled Talks Says Lutnick; No, Says India · US Ready To Give India Access ... 10 hours ago - As it flagged billionaires usurping the political landscape globally, rights group Oxfam on Monday cited India's reservation system as a "compelling" example of progress on how ordinary people can be politically empowered. Prince Harry is to return to London this week for the trial into his claims that a UK newspaper group unlawfully gathered information, in the royal's last case in his long-running crusade against the media.

# %% [markdown]
# BUILD IN SHELL TOOL

# %%
from langchain_community.tools import ShellTool
shell_tool = ShellTool()
results = shell_tool.invoke('whoami')
print(results)
# Out:
# Executing command:
#  whoami
# root
# /usr/local/lib/python3.12/dist-packages/langchain_community/tools/shell/tool.py:33: UserWarning: The shell tool has no safeguards by default. Use at your own risk.
#   warnings.warn(

# %% [markdown]
# # ALL TYPE OF TOOLS AVAILABLE IN LANGCHAIN :- https://docs.langchain.com/oss/python/integrations/tools
